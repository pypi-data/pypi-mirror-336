# %%
pip install llmstxt-architect
# Out:
# Collecting llmstxt-architect
#   Using cached llmstxt_architect-0.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting beautifulsoup4>=4.13.3 (from llmstxt-architect)
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting httpx>=0.28.1 (from llmstxt-architect)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-anthropic>=0.3.10 (from llmstxt-architect)
#   Using cached langchain_anthropic-0.3.10-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-community>=0.3.20 (from llmstxt-architect)
#   Using cached langchain_community-0.3.20-py3-none-any.whl.metadata (2.4 kB)
# Collecting langchain>=0.3.21 (from llmstxt-architect)
#   Using cached langchain-0.3.21-py3-none-any.whl.metadata (7.8 kB)
# Collecting lxml>=5.3.1 (from llmstxt-architect)
#   Using cached lxml-5.3.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (3.7 kB)
# Collecting markdownify>=1.1.0 (from llmstxt-architect)
#   Using cached markdownify-1.1.0-py3-none-any.whl.metadata (9.1 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.13.3->llmstxt-architect)
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4>=4.13.3->llmstxt-architect)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting anyio (from httpx>=0.28.1->llmstxt-architect)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->llmstxt-architect) (2025.1.31)
# Collecting httpcore==1.* (from httpx>=0.28.1->llmstxt-architect)
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->llmstxt-architect) (3.10)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.28.1->llmstxt-architect)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting langchain-core<1.0.0,>=0.3.45 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached langchain_core-0.3.47-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.7 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached langchain_text_splitters-0.3.7-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached langsmith-0.3.18-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached sqlalchemy-2.0.39-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: requests<3,>=2 in ./.venv/lib/python3.13/site-packages (from langchain>=0.3.21->llmstxt-architect) (2.32.3)
# Collecting PyYAML>=5.3 (from langchain>=0.3.21->llmstxt-architect)
#   Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting anthropic<1,>=0.49.0 (from langchain-anthropic>=0.3.10->llmstxt-architect)
#   Using cached anthropic-0.49.0-py3-none-any.whl.metadata (24 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached aiohttp-3.11.14-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting tenacity!=8.4.0,<10,>=8.1.0 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached pydantic_settings-2.8.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numpy<3,>=1.26.2 (from langchain-community>=0.3.20->llmstxt-architect)
#   Using cached numpy-2.2.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (116 kB)
# Requirement already satisfied: six<2,>=1.15 in ./.venv/lib/python3.13/site-packages (from markdownify>=1.1.0->llmstxt-architect) (1.17.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached frozenlist-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached multidict-6.2.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached propcache-0.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached yarl-1.18.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (69 kB)
# Collecting distro<2,>=1.7.0 (from anthropic<1,>=0.49.0->langchain-anthropic>=0.3.10->llmstxt-architect)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from anthropic<1,>=0.49.0->langchain-anthropic>=0.3.10->llmstxt-architect)
#   Using cached jiter-0.9.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from anthropic<1,>=0.49.0->langchain-anthropic>=0.3.10->llmstxt-architect)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.45->langchain>=0.3.21->llmstxt-architect)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in ./.venv/lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain>=0.3.21->llmstxt-architect) (24.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain>=0.3.21->llmstxt-architect)
#   Using cached orjson-3.10.15-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./.venv/lib/python3.13/site-packages (from langsmith<0.4,>=0.1.17->langchain>=0.3.21->llmstxt-architect) (1.0.0)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain>=0.3.21->llmstxt-architect)
#   Using cached zstandard-0.23.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain>=0.3.21->llmstxt-architect)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.7.4->langchain>=0.3.21->llmstxt-architect)
#   Using cached pydantic_core-2.27.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain>=0.3.21->llmstxt-architect) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests<3,>=2->langchain>=0.3.21->llmstxt-architect) (2.3.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain>=0.3.21->llmstxt-architect)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.20->llmstxt-architect)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached llmstxt_architect-0.1.0-py3-none-any.whl (13 kB)
# Using cached beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Using cached langchain-0.3.21-py3-none-any.whl (1.0 MB)
# Using cached langchain_anthropic-0.3.10-py3-none-any.whl (25 kB)
# Using cached langchain_community-0.3.20-py3-none-any.whl (2.5 MB)
# Using cached lxml-5.3.1-cp313-cp313-macosx_10_13_universal2.whl (8.2 MB)
# Using cached markdownify-1.1.0-py3-none-any.whl (13 kB)
# Using cached aiohttp-3.11.14-cp313-cp313-macosx_11_0_arm64.whl (453 kB)
# Using cached anthropic-0.49.0-py3-none-any.whl (243 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Using cached langchain_core-0.3.47-py3-none-any.whl (417 kB)
# Using cached langchain_text_splitters-0.3.7-py3-none-any.whl (32 kB)
# Using cached langsmith-0.3.18-py3-none-any.whl (351 kB)
# Using cached numpy-2.2.4-cp313-cp313-macosx_11_0_arm64.whl (14.1 MB)
# Using cached pydantic-2.10.6-py3-none-any.whl (431 kB)
# Using cached pydantic_core-2.27.2-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
# Using cached pydantic_settings-2.8.1-py3-none-any.whl (30 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl (171 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached sqlalchemy-2.0.39-cp313-cp313-macosx_11_0_arm64.whl (2.1 MB)
# Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (50 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jiter-0.9.0-cp313-cp313-macosx_11_0_arm64.whl (318 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached multidict-6.2.0-cp313-cp313-macosx_11_0_arm64.whl (29 kB)
# Using cached orjson-3.10.15-cp313-cp313-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (249 kB)
# Using cached propcache-0.3.0-cp313-cp313-macosx_11_0_arm64.whl (44 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.18.3-cp313-cp313-macosx_11_0_arm64.whl (91 kB)
# Using cached zstandard-0.23.0-cp313-cp313-macosx_11_0_arm64.whl (633 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: zstandard, typing-extensions, tenacity, soupsieve, sniffio, PyYAML, python-dotenv, propcache, orjson, numpy, mypy-extensions, multidict, marshmallow, lxml, jsonpointer, jiter, httpx-sse, h11, frozenlist, distro, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, pydantic-core, jsonpatch, httpcore, beautifulsoup4, anyio, aiosignal, pydantic, markdownify, httpx, dataclasses-json, aiohttp, pydantic-settings, langsmith, anthropic, langchain-core, langchain-text-splitters, langchain-anthropic, langchain, langchain-community, llmstxt-architect
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.39 aiohappyeyeballs-2.6.1 aiohttp-3.11.14 aiosignal-1.3.2 annotated-types-0.7.0 anthropic-0.49.0 anyio-4.9.0 attrs-25.3.0 beautifulsoup4-4.13.3 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.5.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 httpx-sse-0.4.0 jiter-0.9.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.21 langchain-anthropic-0.3.10 langchain-community-0.3.20 langchain-core-0.3.47 langchain-text-splitters-0.3.7 langsmith-0.3.18 llmstxt-architect-0.1.0 lxml-5.3.1 markdownify-1.1.0 marshmallow-3.26.1 multidict-6.2.0 mypy-extensions-1.0.0 numpy-2.2.4 orjson-3.10.15 propcache-0.3.0 pydantic-2.10.6 pydantic-core-2.27.2 pydantic-settings-2.8.1 python-dotenv-1.0.1 sniffio-1.3.1 soupsieve-2.6 tenacity-9.0.0 typing-extensions-4.12.2 typing-inspect-0.9.0 yarl-1.18.3 zstandard-0.23.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import asyncio
from llmstxt_architect.main import generate_llms_txt

# In Jupyter/IPython, use await 
await generate_llms_txt(
      urls=["https://langchain-ai.github.io/langgraph/concepts"],
      max_depth=1,
      llm_name="claude-3-7-sonnet-latest",
      llm_provider="anthropic",
      project_dir="test",
  )
# Out:
# /Users/rlm/Desktop/Code/llmstxt_generator/.venv/lib/python3.13/site-packages/bs4/__init__.py:867: RuntimeWarning: coroutine 'generate_llms_txt' was never awaited
#   def object_was_parsed(
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Loaded 1 documents from URLs.
#
# Loaded URLs:
# 1. https://langchain-ai.github.io/langgraph/concepts
# Summarizing: https://langchain-ai.github.io/langgraph/concepts
# Generating final llms.txt file from all available summaries...
# Generated test/llms.txt with 1 unique summaries sorted by URL.
